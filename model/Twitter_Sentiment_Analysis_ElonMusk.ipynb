# %% [markdown]
# ## Twitter Sentiment Analysis
# ### Elon Musk Tweets

# %%
# Perform sentimental analysis on the Elon-musk tweets (Elon-musk.csv)

# %%
pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-4.4.0-py2.py3-none-any.whl (65 kB)
# Requirement already satisfied: requests<3,>=2.11.1 in c:\users\91901\anaconda3\lib\site-packages (from tweepy) (2.24.0)
# Requirement already satisfied: requests-oauthlib<2,>=1.0.0 in c:\users\91901\anaconda3\lib\site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\91901\anaconda3\lib\site-packages (from requests<3,>=2.11.1->tweepy) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\91901\anaconda3\lib\site-packages (from requests<3,>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\91901\anaconda3\lib\site-packages (from requests<3,>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91901\anaconda3\lib\site-packages (from requests<3,>=2.11.1->tweepy) (2021.5.30)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\91901\anaconda3\lib\site-packages (from requests-oauthlib<2,>=1.0.0->tweepy) (3.1.0)
# Installing collected packages: tweepy
# Successfully installed tweepy-4.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: nltk>=3.1; python_version >= "3" in c:\users\91901\anaconda3\lib\site-packages (from textblob) (3.5)
# Requirement already satisfied: joblib in c:\users\91901\anaconda3\lib\site-packages (from nltk>=3.1; python_version >= "3"->textblob) (0.17.0)
# Requirement already satisfied: click in c:\users\91901\anaconda3\lib\site-packages (from nltk>=3.1; python_version >= "3"->textblob) (7.1.2)
# Requirement already satisfied: regex in c:\users\91901\anaconda3\lib\site-packages (from nltk>=3.1; python_version >= "3"->textblob) (2020.10.15)
# Requirement already satisfied: tqdm in c:\users\91901\anaconda3\lib\site-packages (from nltk>=3.1; python_version >= "3"->textblob) (4.50.2)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import tweepy
import re

# %%
df= pd.read_csv('Elon_musk.csv',encoding='cp1252')
df.head()
# Out:
#    Unnamed: 0                                               Text
# 0           1                             @kunalb11 I’m an alien
# 1           2  @ID_AA_Carmack Ray tracing on Cyberpunk with H...
# 2           3                @joerogan @Spotify Great interview!
# 3           4                    @gtera27 Doge is underestimated
# 4           5  @teslacn Congratulations Tesla China for amazi...

# %%
import re
# Clean The Data
def cleantext(text):
    text = re.sub(r"@[A-Za-z0-9]+", "", text) # Remove Mentions
    text = re.sub(r"#", "", text) # Remove Hashtags Symbol
    text = re.sub(r"RT[\s]+", "", text) # Remove Retweets
    text = re.sub(r"https?:\/\/\S+", "", text) # Remove The Hyper Link
    
    return text

# %%
# Clean The Text
df["Text"] = df["Text"].apply(cleantext)
df.head()
# Out:
#    Unnamed: 0                                               Text
# 0           1                                       I’m an alien
# 1           2  _AA_Carmack Ray tracing on Cyberpunk with HDR ...
# 2           3                                   Great interview!
# 3           4                             Doge is underestimated
# 4           5   Congratulations Tesla China for amazing execu...

# %%
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
from textblob import TextBlob
# Get The Subjectivity
def sentiment_analysis(ds):
    sentiment = TextBlob(ds["Text"]).sentiment
    return pd.Series([sentiment.subjectivity, sentiment.polarity])
# Adding Subjectivity & Polarity
df[["subjectivity", "polarity"]] = df.apply(sentiment_analysis, axis=1)
df
# Out:
#                                                    Text  subjectivity  \
# 0                                          I’m an alien      0.750000
# 1     _AA_Carmack Ray tracing on Cyberpunk with HDR ...      0.000000
# 2                                      Great interview!      0.750000
# 3                                Doge is underestimated      0.000000
# 4      Congratulations Tesla China for amazing execu...      0.366667
# ...                                                 ...           ...
# 1994   True, it sounds so surreal, but the negative ...      0.508333
# 1995   Make sure to read ur terms &amp; conditions b...      0.888889
# 1996                                     Samwise Gamgee      0.000000
# 1997   Altho Dumb and Dumber is <U+0001F525><U+0001F...      0.500000
# 1998                          Progress update August 28      0.000000
#
#       polarity
# 0    -0.250000
# 1     0.000000
# 2     1.000000
# 3     0.000000
# 4     0.345313
# ...        ...
# 1994  0.111111
# 1995  0.625000
# 1996  0.000000
# 1997 -0.375000
# 1998  0.000000
#
# [1999 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
allwords = " ".join([twts for twts in df["Text"]])
wordCloud = WordCloud(width = 1000, height = 1000, random_state = 21, max_font_size = 119).generate(allwords)
plt.figure(figsize=(10, 10), dpi=80)
plt.imshow(wordCloud, interpolation = "bilinear")
plt.axis("off")
plt.show()

# %%
# Compute The Negative, Neutral, Positive Analysis
def analysis(score):
    if score < 0:
        return "Negative"
    elif score == 0:
        return "Neutral"
    else:
        return "Positive"

# %%
# Create a New Analysis Column
df["analysis"] = df["polarity"].apply(analysis)
# Print The Data
df
# Out:
#                                                    Text  subjectivity  \
# 0                                          I’m an alien      0.750000
# 1     _AA_Carmack Ray tracing on Cyberpunk with HDR ...      0.000000
# 2                                      Great interview!      0.750000
# 3                                Doge is underestimated      0.000000
# 4      Congratulations Tesla China for amazing execu...      0.366667
# ...                                                 ...           ...
# 1994   True, it sounds so surreal, but the negative ...      0.508333
# 1995   Make sure to read ur terms &amp; conditions b...      0.888889
# 1996                                     Samwise Gamgee      0.000000
# 1997   Altho Dumb and Dumber is <U+0001F525><U+0001F...      0.500000
# 1998                          Progress update August 28      0.000000
#
#       polarity  analysis
# 0    -0.250000  Negative
# 1     0.000000   Neutral
# 2     1.000000  Positive
# 3     0.000000   Neutral
# 4     0.345313  Positive
# ...        ...       ...
# 1994  0.111111  Positive
# 1995  0.625000  Positive
# 1996  0.000000   Neutral
# 1997 -0.375000  Negative
# 1998  0.000000   Neutral
#
# [1999 rows x 4 columns]

# %%
plt.figure(figsize=(10, 8))
for i in range(0, df.shape[0]):
    plt.scatter(df["polarity"][i], df["subjectivity"][i], color = "Red")
plt.title("Sentiment Analysis") # Add The Graph Title
plt.xlabel("Polarity") # Add The X-Label
plt.ylabel("Subjectivity") # Add The Y-Label
plt.show() # Showing The Graph
